# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
labels = np.load('./Embeddings/y_dev_sensor_Magn_seqLen150_bdb.npz')['arr_0']
labelsId =  np.load('./Embeddings/y_dev_id_sensor_Magn_seqLen150_bdb.npz')['arr_0']

# %%
dataMat_id = np.zeros(shape=(51,1))
dataMat_gest = np.zeros(shape=(4,1))
dataMat = np.zeros(shape=(4,51))

def plotGramMatrix(cm,
                   cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    ax = sns.heatmap(cm, cmap=cmap, linewidth=0.5, linecolor='black')
    plt.show()

# %%
for idx, labelCurr in enumerate(labels):
    dataMat_gest[labelCurr,:] = dataMat_gest[labelCurr,:] + 1

plt.bar(np.arange(1,5),dataMat_gest[:,0])
plt.show()

# %%
for idx, labelCurr in enumerate(labelsId):
    dataMat_id[labelCurr,:] = dataMat_id[labelCurr,:] + 1

plt.bar(np.arange(1,52),dataMat_id[:,0])
plt.show()

# %%
for labelGestCurr, labelIdCurr in zip(labels,labelsId):
    dataMat[labelGestCurr,labelIdCurr] = dataMat[labelGestCurr,labelIdCurr] + 1

print(dataMat)
plotGramMatrix(dataMat)
# Out:
# [[51. 33. 37. 19. 16. 20. 16. 31.  7. 20. 17. 19. 12. 13. 25. 19. 13.  9.
#   13. 27.  7. 17. 11. 25. 34. 31. 22. 29. 33. 11. 28. 15. 14. 22. 10. 63.
#   21. 32. 25.  9. 14. 25. 19. 70. 25.  9. 13. 45. 15. 13. 31.]
#  [14. 52. 11.  5.  7.  4.  3. 11.  1.  9. 11.  7.  3.  3. 12.  8.  8.  5.
#    8.  7.  4.  4.  2.  3. 11.  6. 10.  9.  6.  2. 13.  4.  5.  9.  4. 21.
#   25.  9.  9. 10. 14. 10.  4. 19. 12.  3.  6. 25.  4. 21. 49.]
#  [11.  5. 11.  7.  3.  8.  2.  7.  2.  7.  5.  5.  3.  3.  5.  5.  3. 10.
#    3.  6.  2.  3.  3.  4.  9.  7.  9.  5.  5.  3.  9.  6.  4. 10.  3.  5.
#    6.  5.  8.  7.  5.  7.  6. 18.  9.  1.  3. 11.  3.  4.  5.]
#  [ 2.  2.  2.  1.  1.  5.  0.  1.  1.  2.  2.  1.  1.  1.  1.  2.  1.  1.
#    3.  1.  1.  1.  1.  1.  2.  2.  2.  1.  2.  1.  2.  1.  1.  1.  1.  2.
#    1.  2.  2.  4.  1.  1.  1.  2.  2.  0.  1.  1.  1.  0.  1.]]

# %%
plotGramMatrix(dataMat > 1)
